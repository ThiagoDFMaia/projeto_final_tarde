# %% [markdown]
# # Introdução a Banco de dados

# %% [markdown]
# # Desafio:
# * inserir um aluno na tabela Aluno
# * Utilizar nossa RA e inserir nosso diario de bordo da aula de hoje na tabela diarioBordo

# %% [markdown]
# # Scripts do desafio
# * INSERT INTO Aluno (ra) VALUES ('00176120');
# * INSERT INTO diarioBordo (texto, dataHora, fk_Aluno_id) VALUES ('Hoje aprendemos a inserir dados na tabela no banco de dados e fazer select utilizando a clausula join para unir 2 tabelas distintas.', '2024-07-31 08:00:00', 156);
#
# * select
#   d.id,
#   d.texto,
#   d.dataHora,
#   a.ra as registro_academico
#   from aluno a
#   join diarioBordo d
#   on d.fk_Aluno_id=a.id
#   where a.id=156

# %% [markdown]
# # Scripts da criação do BD
#
# ### -- DDL (Data definition language)-- linguagem de definição de dados
# ### -- CREATE -> create database (criar um database)
# * create database schooltracker;
#
# ###  -- seleciona o database
# * use schooltracker;
#
# ###  -- lista as tabelas
# * show tables;
#
# # criar as tabelas
#
# * CREATE TABLE Aluno (
#     id int PRIMARY KEY auto_increment,
#     ra CHAR(8) not null
# );
#
#
# * CREATE TABLE diarioBordo (
#     texto text not null,
#     id int PRIMARY KEY auto_increment,
#     dataHora datetime,
#     fk_Aluno_id int
# );
# ### Alterando as tabelas
#
# * ALTER TABLE diarioBordo ADD CONSTRAINT FK_diarioBordo_2
#     FOREIGN KEY (fk_Aluno_id)
#     REFERENCES Aluno (id)
#     ON DELETE CASCADE;
#
# * ALTER TABLE Aluno
# ADD CONSTRAINT unique_ra UNIQUE (ra);
#
#
# ### inserindo os dados
#
#
# INSERT INTO Aluno (ra) VALUES ('00034548');
# INSERT INTO Aluno (ra) VALUES ('00034549');
# INSERT INTO Aluno (ra) VALUES ('00034550');
# INSERT INTO Aluno (ra) VALUES ('00034551');
# INSERT INTO Aluno (ra) VALUES ('00034552');
# INSERT INTO Aluno (ra) VALUES ('00034553');
# INSERT INTO Aluno (ra) VALUES ('00034554');
# INSERT INTO Aluno (ra) VALUES ('00034555');
# INSERT INTO Aluno (ra) VALUES ('00034556');
# INSERT INTO Aluno (ra) VALUES ('00034557');
# INSERT INTO Aluno (ra) VALUES ('00034558');
# INSERT INTO Aluno (ra) VALUES ('00034559');
# INSERT INTO Aluno (ra) VALUES ('00034560');
# INSERT INTO Aluno (ra) VALUES ('00034561');
# INSERT INTO Aluno (ra) VALUES ('00034562');
# INSERT INTO Aluno (ra) VALUES ('00034563');
# INSERT INTO Aluno (ra) VALUES ('00034564');
# INSERT INTO Aluno (ra) VALUES ('00034565');
# INSERT INTO Aluno (ra) VALUES ('00034566');
# INSERT INTO Aluno (ra) VALUES ('00034567');
# INSERT INTO Aluno (ra) VALUES ('00034568');
# INSERT INTO Aluno (ra) VALUES ('00034569');
# INSERT INTO Aluno (ra) VALUES ('00034570');
# INSERT INTO Aluno (ra) VALUES ('00034571');
# INSERT INTO Aluno (ra) VALUES ('00034572');
# INSERT INTO Aluno (ra) VALUES ('00034573');
# INSERT INTO Aluno (ra) VALUES ('00034574');
# INSERT INTO Aluno (ra) VALUES ('00034575');
# INSERT INTO Aluno (ra) VALUES ('00034576');
# INSERT INTO Aluno (ra) VALUES ('00034577');
# INSERT INTO Aluno (ra) VALUES ('00034578');
# INSERT INTO Aluno (ra) VALUES ('00034579');
# INSERT INTO Aluno (ra) VALUES ('00034580');
# INSERT INTO Aluno (ra) VALUES ('00034581');
# INSERT INTO Aluno (ra) VALUES ('00034582');
# INSERT INTO Aluno (ra) VALUES ('00034583');
# INSERT INTO Aluno (ra) VALUES ('00034584');
# INSERT INTO Aluno (ra) VALUES ('00034585');
# INSERT INTO Aluno (ra) VALUES ('00034586');
# INSERT INTO Aluno (ra) VALUES ('00034587');
# INSERT INTO Aluno (ra) VALUES ('00034588');
# INSERT INTO Aluno (ra) VALUES ('00034589');
# INSERT INTO Aluno (ra) VALUES ('00034590');
# INSERT INTO Aluno (ra) VALUES ('00034591');
# INSERT INTO Aluno (ra) VALUES ('00034592');
# INSERT INTO Aluno (ra) VALUES ('00034593');
# INSERT INTO Aluno (ra) VALUES ('00034594');
# INSERT INTO Aluno (ra) VALUES ('00034595');
# INSERT INTO Aluno (ra) VALUES ('00034596');
# INSERT INTO Aluno (ra) VALUES ('00034597');
# INSERT INTO Aluno (ra) VALUES ('00034598');
# INSERT INTO Aluno (ra) VALUES ('00034599');
# INSERT INTO Aluno (ra) VALUES ('00034600');
# INSERT INTO Aluno (ra) VALUES ('00034601');
# INSERT INTO Aluno (ra) VALUES ('00034602');
# INSERT INTO Aluno (ra) VALUES ('00034603');
# INSERT INTO Aluno (ra) VALUES ('00034604');
# INSERT INTO Aluno (ra) VALUES ('00034605');
# INSERT INTO Aluno (ra) VALUES ('00034606');
# INSERT INTO Aluno (ra) VALUES ('00034607');
# INSERT INTO Aluno (ra) VALUES ('00034608');
# INSERT INTO Aluno (ra) VALUES ('00034609');
# INSERT INTO Aluno (ra) VALUES ('00034610');
# INSERT INTO Aluno (ra) VALUES ('00034611');
# INSERT INTO Aluno (ra) VALUES ('00034612');
# INSERT INTO Aluno (ra) VALUES ('00034613');
# INSERT INTO Aluno (ra) VALUES ('00034614');
# INSERT INTO Aluno (ra) VALUES ('00034615');
# INSERT INTO Aluno (ra) VALUES ('00034616');
# INSERT INTO Aluno (ra) VALUES ('00034617');
# INSERT INTO Aluno (ra) VALUES ('00034618');
# INSERT INTO Aluno (ra) VALUES ('00034619');
# INSERT INTO Aluno (ra) VALUES ('00034620');
# INSERT INTO Aluno (ra) VALUES ('00034621');
# INSERT INTO Aluno (ra) VALUES ('00034622');
# INSERT INTO Aluno (ra) VALUES ('00034623');
# INSERT INTO Aluno (ra) VALUES ('00034624');
# INSERT INTO Aluno (ra) VALUES ('00034625');
# INSERT INTO Aluno (ra) VALUES ('00034626');
# INSERT INTO Aluno (ra) VALUES ('00034627');
# INSERT INTO Aluno (ra) VALUES ('00034628');
# INSERT INTO Aluno (ra) VALUES ('00034629');
# INSERT INTO Aluno (ra) VALUES ('00034630');
# INSERT INTO Aluno (ra) VALUES ('00034631');
# INSERT INTO Aluno (ra) VALUES ('00034632');
# INSERT INTO Aluno (ra) VALUES ('00034633');
# INSERT INTO Aluno (ra) VALUES ('00034634');
# INSERT INTO Aluno (ra) VALUES ('00034635');
# INSERT INTO Aluno (ra) VALUES ('00034636');
# INSERT INTO Aluno (ra) VALUES ('00034637');
# INSERT INTO Aluno (ra) VALUES ('00034638');
# INSERT INTO Aluno (ra) VALUES ('00034639');
# INSERT INTO Aluno (ra) VALUES ('00034640');
# INSERT INTO Aluno (ra) VALUES ('00034641');
# INSERT INTO Aluno (ra) VALUES ('00034642');
# INSERT INTO Aluno (ra) VALUES ('00034643');
# INSERT INTO Aluno (ra) VALUES ('00034644');
# INSERT INTO Aluno (ra) VALUES ('00034645');
# INSERT INTO Aluno (ra) VALUES ('00034646');
# INSERT INTO Aluno (ra) VALUES ('00034647');
# INSERT INTO Aluno (ra) VALUES ('00034648');
# INSERT INTO Aluno (ra) VALUES ('00034649');
# INSERT INTO Aluno (ra) VALUES ('00034650');
# INSERT INTO Aluno (ra) VALUES ('00034651');
# INSERT INTO Aluno (ra) VALUES ('00034652');
# INSERT INTO Aluno (ra) VALUES ('00034653');
# INSERT INTO Aluno (ra) VALUES ('00034654');
# INSERT INTO Aluno (ra) VALUES ('00034655');
# INSERT INTO Aluno (ra) VALUES ('00034656');
# INSERT INTO Aluno (ra) VALUES ('00034657');
# INSERT INTO Aluno (ra) VALUES ('00034658');
# INSERT INTO Aluno (ra) VALUES ('00034659');
# INSERT INTO Aluno (ra) VALUES ('00034660');
# INSERT INTO Aluno (ra) VALUES ('00034661');
# INSERT INTO Aluno (ra) VALUES ('00034662');
# INSERT INTO Aluno (ra) VALUES ('00034663');
# INSERT INTO Aluno (ra) VALUES ('00034664');
# INSERT INTO Aluno (ra) VALUES ('00034665');
# INSERT INTO Aluno (ra) VALUES ('00034666');
# INSERT INTO Aluno (ra) VALUES ('00034667');
# INSERT INTO Aluno (ra) VALUES ('00034668');
# INSERT INTO Aluno (ra) VALUES ('00034669');
# INSERT INTO Aluno (ra) VALUES ('00034670');
# INSERT INTO Aluno (ra) VALUES ('00034671');
# INSERT INTO Aluno (ra) VALUES ('00034672');
# INSERT INTO Aluno (ra) VALUES ('00034673');
# INSERT INTO Aluno (ra) VALUES ('00034674');
# INSERT INTO Aluno (ra) VALUES ('00034675');
# INSERT INTO Aluno (ra) VALUES ('00034676');
# INSERT INTO Aluno (ra) VALUES ('00034677');
# INSERT INTO Aluno (ra) VALUES ('00034678');
# INSERT INTO Aluno (ra) VALUES ('00034679');
# INSERT INTO Aluno (ra) VALUES ('00034680');
# INSERT INTO Aluno (ra) VALUES ('00034681');
# INSERT INTO Aluno (ra) VALUES ('00034682');
# INSERT INTO Aluno (ra) VALUES ('00034683');
# INSERT INTO Aluno (ra) VALUES ('00034684');
# INSERT INTO Aluno (ra) VALUES ('00034685');
# INSERT INTO Aluno (ra) VALUES ('00034686');
# INSERT INTO Aluno (ra) VALUES ('00034687');
# INSERT INTO Aluno (ra) VALUES ('00034688');
# INSERT INTO Aluno (ra) VALUES ('00034689');
# INSERT INTO Aluno (ra) VALUES ('00034690');
# INSERT INTO Aluno (ra) VALUES ('00034691');
# INSERT INTO Aluno (ra) VALUES ('00034692');
# INSERT INTO Aluno (ra) VALUES ('00034693');
# INSERT INTO Aluno (ra) VALUES ('00034694');
# INSERT INTO Aluno (ra) VALUES ('00034695');
# INSERT INTO Aluno (ra) VALUES ('00034696');
# INSERT INTO Aluno (ra) VALUES ('00034697');
# INSERT INTO Aluno (ra) VALUES ('00034698');
# INSERT INTO Aluno (ra) VALUES ('00034699');
# INSERT INTO Aluno (ra) VALUES ('00034700');
# INSERT INTO Aluno (ra) VALUES ('00034701');
#
# ### Inserindo meu ra pessoal
# * INSERT INTO Aluno (ra) VALUES ('00176120');
#
#
#
# ### Selecionando alunos e o diario de bordo : pela ra do aluno
# * select *from aluno a join diariobordo d on a.id=d.fk_Aluno_id;
#
#
# ### Selecionando alunos e o diario de bodo : pelo id do aluno
# * select
#   d.id,
#   d.texto,
#   d.dataHora,
#   a.ra as registro_academico
#   from aluno a
#   join diarioBordo d
#   on d.fk_Aluno_id=a.id
#   where a.id=156

# %% [markdown]
# # Modelo do BD
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Desafio: criar uma tabela avaliacao
# ### Com as seguintes colunas:
# * nota1
# * nota2
# * nota3
# * nota4
# * fk_aluno
#
# ### Inserir 5 avaliações e fazer um select
#
# ### Fazer o modelo logico e conceitutal

# %% [markdown]
# ### Modelo lógico
# ![image.png](attachment:image.png)
#
# ### Modelo conceitual
# ![image-2.png](attachment:image-2.png)
#
#
# ### criação da tabela:
#
# * CREATE TABLE Avaliacao (
#     id int PRIMARY KEY auto_increment,
#     nota1 int,
#     nota2 int,
#     nota3 int,
#     nota4 int,
#     fk_Aluno_id int
# );
#
# ### Alterando fk_Aluno_id int para constraint
#
# * ALTER TABLE avaliacao ADD CONSTRAINT FK_avaliacao_2
#     FOREIGN KEY (fk_Aluno_id)
#     REFERENCES Aluno (id)
#     ON DELETE CASCADE;
#
# ### inserts
# * INSERT INTO Avaliacao (nota1, nota2, nota3,nota4,fk_Aluno_id) VALUES (10,9,8,7,156);
# * INSERT INTO Avaliacao (nota1, nota2, nota3,nota4,fk_Aluno_id) VALUES (8,5,6,7,155);
# * INSERT INTO Avaliacao (nota1, nota2, nota3,nota4,fk_Aluno_id) VALUES (4,7,8,10,154);
# * INSERT INTO Avaliacao (nota1, nota2, nota3,nota4,fk_Aluno_id) VALUES (3,5,9,6,153);
# * INSERT INTO Avaliacao (nota1, nota2, nota3,nota4,fk_Aluno_id) VALUES (2,10,10,6,152);
#
# ### Select com join entre avaliacao e aluno
#
# * select *
# from avaliacao av
# join aluno al
# on al.id=av.fk_aluno_id
#
# ### Resultado
#
# ![image-3.png](attachment:image-3.png)
